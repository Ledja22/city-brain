# %%
# !pip install lightgbm shap lime lief xgboost
# !pip install git+https://github.com/elastic/ember.git

#%%
import os
import importlib
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import lightgbm as lgb
import xgboost as xgb
import ember

from scipy import stats

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

import shap
import lime
import lime.lime_tabular

importlib.reload(ember)

sns.set_theme(style="whitegrid")
np.random.seed(42)

print("All imports successful!")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 20.8 MB/s eta 0:00:00
# ...
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=58fdbb2ebbe5688ad2b97b6b48d58e285e762f605cf908aca6a22af70d5250bd
#   Stored in directory: /root/.cache/pip/wheels/e7/5d/0e/4b4fff9a47468fed5633211fb3b76d1db43fe806a17fb7486a
# Successfully built lime
# ...
#   Cloning https://github.com/elastic/ember.git to /tmp/pip-req-build-u9wt1ilq
#   Running command git clone --filter=blob:none --quiet https://github.com/elastic/ember.git /tmp/pip-req-build-u9wt1ilq
#   Resolved https://github.com/elastic/ember.git to commit d97a0b523de02f3fe5ea6089d080abacab6ee931
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ember: filename=ember-0.1.0-py3-none-any.whl size=13049 sha256=f5c062e5e770dc6f7254602e61e3317be51e6ca05284b24c9cd0b7eda36c5ada
# ...

# %% [markdown]
# ### Pavement condition rating records

# %%
import requests
import pandas as pd

# API endpoint
url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/pavement-condition-rating/records"

# Parameters
# params = {
#     "limit": 100
# }

# Request data
response = requests.get(url, params=params)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data["results"])

# preview
df.head()
# Out:
#    year road_name   from_street    to_street  length_m pci_rating  \
# 0  2020   47TH AV  FRONTENAC ST  KIRKLAND ST        89       GOOD
# 1  2020   62ND AV   LABURNUM ST  ANGUS DRIVE       206  VERY POOR
# 2  2020   29TH AV      ELGIN ST      ROSS ST       101       POOR
# 3  2020   31ST AV     LANARK ST  DUMFRIES ST        93  VERY POOR
# 4  2020   53RD AV     KNIGHT ST    LANARK ST       100  VERY GOOD
#
#                                                 geom  \
# 0  {'type': 'Feature', 'geometry': {'coordinates'...
# 1  {'type': 'Feature', 'geometry': {'coordinates'...
# 2  {'type': 'Feature', 'geometry': {'coordinates'...
# 3  {'type': 'Feature', 'geometry': {'coordinates'...
# 4  {'type': 'Feature', 'geometry': {'coordinates'...
#
#                                         geo_point_2d
# 0  {'lon': -123.02535015595373, 'lat': 49.2263749...
# 1  {'lon': -123.1498338331115, 'lat': 49.21508347...
# 2  {'lon': -123.08202889157728, 'lat': 49.2446059...
# ...

# %% [markdown]
# ### 3-1-1 Service requests

# %%
import requests
import pandas as pd

# API endpoint
url = "https://opendata.vancouver.ca/api/explore/v2.1/catalog/datasets/3-1-1-service-requests/records"

# Parameters
# params = {
#     "limit": 100
# }

# Request data
response = requests.get(url, params=params)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data["results"])

# preview
df.head()
# Out:
#                                           department  \
# 0                           ENG - Streets Operations
# 1                                 311 Contact Centre
# 2                          ENG - Sanitation Services
# 3  ENG - Traffic and Electrical Operations and De...
# 4           ENG - Parking Enforcement and Operations
#
#                             service_request_type status  \
# 0  Vegetation Encroachment of City Property Case  Close
# 1                          General Feedback Case  Close
# 2           Abandoned Non-Recyclables-Small Case  Close
# 3                          Street Light Out Case  Close
# 4            Abandoned or Uninsured Vehicle Case  Close
#
#                closure_reason service_request_open_timestamp  \
# 0                     Unknown      2022-09-27T03:44:00+00:00
# 1  Alternate Service Required      2022-09-27T03:45:13+00:00
# 2            Service provided      2022-09-27T03:57:03+00:00
# ...

# %% [markdown]
# ### Weather data

# %%
import requests
import pandas as pd

# API endpoint
url = "https://api.weather.gc.ca/collections?f=json&lang=en-CA"


# Request data
response = requests.get(url)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data["collections"])

# preview
df.head()
# Out:
#                               id  \
# 0           hydrometric-stations
# 1         hydrometric-daily-mean
# 2       hydrometric-monthly-mean
# 3  hydrometric-annual-statistics
# 4       hydrometric-annual-peaks
#
#                                                title  \
# 0             Hydrometric Data - Monitoring Stations
# 1  Hydrometric Historical Data (HYDAT) - Daily Me...
# 2  Hydrometric Historical Data (HYDAT) - Monthly ...
# 3  Hydrometric Historical Data (HYDAT) - Annual M...
# 4  Hydrometric Historical Data (HYDAT) - Annual M...
#
#                                          description  \
# 0  A station is a site on a river or lake where w...
# 1  The daily mean is the average of all unit valu...
# 2  The monthly mean is the average of daily mean ...
# 3  The annual maximum and minimum daily data are ...
# 4  The annual maximum and minimum instantaneous d...
#
#                                             keywords  \
# 0                     [station, hydrometric station]
# ...
